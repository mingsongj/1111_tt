# %%
import find_device_path
import serial_communication

path = find_device_path.get_device_path('ttyUSB_Arduino')
print(path)
# Out:
# Symbolic Link Name: ttyUSB_Arduino
# Device Path: /dev/ttyUSB1
#
#
# /dev/ttyUSB1
